# %%
import pandas as pd
result=pd.read_csv('PROJECT_DATASET/s1.csv')
result.head()
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 19 columns):
# NO.                  57 non-null object
# MA101                57 non-null object
# ma_internals         57 non-null object
# PH100                57 non-null object
# ph100_internals      57 non-null int64
#  BE10105             57 non-null object
# be10105_internals    57 non-null int64
# BE110                57 non-null object
# be110_internals      57 non-null int64
#  BE103               57 non-null object
# be103_internals      57 non-null int64
#  EC100               57 non-null object
# ec100_internals      57 non-null int64
#  PH110               57 non-null object
# ph110_internals      57 non-null int64
#  EC110               57 non-null object
# ec110_internals      57 non-null int64
#  CS110               57 non-null object
# cs110_internals      57 non-null int64
# dtypes: int64(8), object(11)
# memory usage: 8.6+ KB

# %%
def nominalToNumber(dataframe,column,mapping):
    dataframe[column] = dataframe[column].map(mapping)
    return dataframe

def encodeData(studentData):
    registerno={
'TRV16IT001':1,
'TRV16IT002':2,
'TRV16IT003':3,
'TRV16IT005':5,
'TRV16IT006':6,
'TRV16IT007':7,
'TRV16IT008':8,
'TRV16IT009':9,
'TRV16IT010':10,
'TRV16IT011':11,
'TRV16IT012':12,
'TRV16IT013':13,
'TRV16IT015':15,
'TRV16IT016':16,
'TRV16IT017':17,
'TRV16IT018':18,
'TRV16IT019':19,
'TRV16IT020':20,
'TRV16IT021':21,
'TRV16IT022':22,
'TRV16IT023':23,
'TRV16IT024':24,
'TRV16IT025':25,
'TRV16IT026':26,
'TRV16IT028':28,
'TRV16IT030':30,
'TRV16IT031':31,
'TRV16IT032':32,
'TRV16IT033':33,
'TRV16IT034':34,
'TRV16IT035':35,
'TRV16IT036':36,
'TRV16IT037':37,
'TRV16IT038':38,
'TRV16IT039':39,
'TRV16IT040':40,
'TRV16IT041':41,
'TRV16IT042':42,
'TRV16IT043':43,
'TRV16IT044':44,
'TRV16IT045':45,
'TRV16IT046':46,
'TRV16IT048':48,
'TRV16IT049':49,
'TRV16IT050':50,
'TRV16IT051':51,
'TRV16IT052':52,
'TRV16IT053':53,
'TRV16IT054':54,
'TRV16IT055':55,
'TRV16IT056':56,
'TRV16IT057':57,
'TRV16IT058':58,
'TRV16IT059':59,
'TRV16IT060':60,
'TRV16IT061':61,
'TRV16IT062':62
}
    studentData = nominalToNumber(studentData,'NO.',registerno)
    
    gradeMapping = {'O':10,'A+':9,'A':8,'B+':7,'B':6,'C':5,'P':4,'F':0,'FE':0,'I':0}
    studentData = nominalToNumber(studentData,'MA101',gradeMapping)
    studentData = nominalToNumber(studentData,'PH100',gradeMapping)
    studentData = nominalToNumber(studentData,' BE10105',gradeMapping)
    studentData = nominalToNumber(studentData,'BE110',gradeMapping)
    studentData = nominalToNumber(studentData,' BE103',gradeMapping)
    studentData = nominalToNumber(studentData,' EC100',gradeMapping)
    studentData = nominalToNumber(studentData,' PH110',gradeMapping)
    studentData = nominalToNumber(studentData,' EC110',gradeMapping)
    studentData = nominalToNumber(studentData,' CS110',gradeMapping)
#     familySizeMapping = {'GT3':0,'LE3':1}
#     studentData = nominalToNumber(studentData,'famsize',familySizeMapping)
    
#     pStatusMapping = {'T':0,'A':1}
#     studentData = nominalToNumber(studentData,'Pstatus',pStatusMapping)
    
#     parentJobMapping = {'at_home':0,'health':1,'other':2,'services':3,'teacher':4}
#     studentData = nominalToNumber(studentData,'Mjob',parentJobMapping)
#     studentData = nominalToNumber(studentData,'Fjob',parentJobMapping)    
    
#     reasonMapping = {'course':0,'other':1,'home':2,'reputation':3}
#     studentData = nominalToNumber(studentData,'reason',reasonMapping)
    
#     guardianMapping = {'mother':0,'father':1,'other':2}
#     studentData = nominalToNumber(studentData ,'guardian' ,guardianMapping)
    
#     yesNoMapping = {'yes':0,'no':1}
#     studentData = nominalToNumber(studentData,'schoolsup',yesNoMapping)
#     studentData = nominalToNumber(studentData,'famsup',yesNoMapping)
#     studentData = nominalToNumber(studentData,'paid',yesNoMapping)
#     studentData = nominalToNumber(studentData,'activities',yesNoMapping)
#     studentData = nominalToNumber(studentData,'nursery',yesNoMapping)
#     studentData = nominalToNumber(studentData,'higher',yesNoMapping)
#     studentData = nominalToNumber(studentData,'internet',yesNoMapping)
#     studentData = nominalToNumber(studentData,'romantic',yesNoMapping)
    return studentData

# %%
result.columns
# Out:
# Index(['NO.', 'MA101', 'ma_internals', 'PH100', 'ph100_internals', ' BE10105',
#        'be10105_internals', 'BE110', 'be110_internals', ' BE103',
#        'be103_internals', ' EC100', 'ec100_internals', ' PH110',
#        'ph110_internals', ' EC110', 'ec110_internals', ' CS110',
#        'cs110_internals'],
#       dtype='object')

# %%
encodeData(result)
# Out:
#     NO.  MA101 ma_internals  PH100  ph100_internals   BE10105  \
# 0     1    0.0           25      0               23       0.0
# 1     2    6.0           41      7               46       7.0
# 2     3   10.0           47     10               50       6.0
# 3     5    6.0           31      9               41       5.0
# 4     6   10.0           45      7               46       0.0
# 5     7    9.0           46      9               47       8.0
# 6     8    5.0           25      6               40       0.0
# 7     9    6.0           31      6               34       5.0
# 8    10    0.0           24      4               24       0.0
# 9    11    9.0           43     10               47       6.0
# 10   12    6.0           36      6               39       5.0
# 11   13    6.0           33      9               42       8.0
# 12   15    9.0           48      7               45       8.0
# 13   16   10.0           44     10               49       9.0
# 14   17    7.0           46      9               46       8.0
# 15   18    NaN      Absent       0               23       0.0
# 16   19    7.0           43      7               38       6.0
# 17   20    7.0           42      6               48       9.0
# 18   21    0.0           30      6               38       0.0
# 19   22   10.0           44      8               42       7.0
# 20   23    7.0           36      8               47       9.0
# 21   24    0.0           26      4               29       NaN
# 22   25    0.0           27      6               27       0.0
# 23   26    8.0           48      9               43       7.0
# 24   28    0.0           27      0               29       0.0
# 25   30    6.0           41      7               43       6.0
# 26   31    0.0           33      5               39       0.0
# 27   32    NaN      Absent       0               23       0.0
# 28   33    8.0           45      6               39       0.0
# 29   34    0.0           23      0               27       7.0
# 30   35    5.0           32      5               34       6.0
# 31   36    5.0           32      6               36       5.0
# 32   37    9.0           45      7               50       0.0
# 33   38    6.0           37      7               50       8.0
# 34   39   10.0           45      8               43       0.0
# 35   40    7.0           38      7               42       5.0
# 36   41    0.0           23      4               26       0.0
# 37   42    8.0           46      7               45       6.0
# 38   43    7.0           43      6               42       5.0
# 39   44    7.0           46      9               47       8.0
# 40   45    7.0           46      7               39       8.0
# 41   46    0.0           26      0               35       9.0
# 42   48    6.0           40      7               49       8.0
# 43   49    5.0           29      6               29       0.0
# 44   50    0.0           24      0               30       0.0
# 45   51    0.0           26      0               29       0.0
# 46   52    8.0           41      9               44       5.0
# 47   53    7.0           46      8               46       9.0
# 48   54    7.0           39      7               43       6.0
# 49   55    6.0           37      5               39       5.0
# 50   56   10.0           50     10               48       7.0
# 51   57    8.0           45      8               46       7.0
# 52   58    5.0           33      6               36       5.0
# 53   59    0.0           26      5               39       5.0
# 54   60    5.0           36      6               33       0.0
# 55   61    6.0           31      4               25       0.0
# 56   62    0.0           27      0               25       5.0
#
#     be10105_internals  BE110  be110_internals   BE103  be103_internals  \
# 0                  35      8               96       5               36
# 1                  47      7               92       7               40
# 2                  47      8               74       9               46
# 3                  42      7               78       9               42
# 4                  40      6               82       7               41
# 5                  48      8               79       8               45
# 6                  37      0               79       7               37
# 7                  35      0               68       6               38
# 8                  38      7               80       7               41
# 9                  45      8               83       9               50
# 10                 35      6               85       6               38
# 11                 46      7               83       7               39
# 12                 48     10               95       7               49
# 13                 50     10               93       8               44
# 14                 50     10               93       8               47
# 15                 38      0               68       0               37
# 16                 40     10               95       7               38
# 17                 50     10               91       8               47
# 18                 38      0               77       6               36
# 19                 45      9               89       6               38
# 20                 50     10               95       8               44
# 21                 40      7               68       7               40
# 22                 42      6               81       7               41
# 23                 46      9               84       8               44
# 24                 38      0               61       7               36
# 25                 38      8               80       7               38
# 26                 37      6               73       8               38
# 27                 35      0               72       5               35
# 28                 47      0               92       9               40
# 29                 38      0               72       7               38
# 30                 38      7               66       7               42
# 31                 38      6               74       7               39
# 32                 48      8               84       7               44
# 33                 45      6               68       7               39
# 34                 42     10               94       8               40
# 35                 41      7               78       7               38
# 36                 38      7               83       6               38
# 37                 43      7               79       7               43
# 38                 40      9               93       7               40
# 39                 45      7               82       7               37
# 40                 46      8               84       6               39
# 41                 38      6               81       6               37
# 42                 38      0               78       6               37
# 43                 44      7               91       7               37
# 44                 39      0               69       7               40
# 45                 38      0               78       0               39
# 46                 42      9               94       7               45
# 47                 49      7               94       8               48
# 48                 43      7               84       8               46
# 49                 46      7               80       6               41
# 50                 45      9               93       6               40
# 51                 42      9               95       7               41
# 52                 36      7               88       6               38
# 53                 40      6               89       7               36
# 54                 40      7               90       6               39
# 55                 42      0               63       5               35
# 56                 38      7               80       6               35
#
#      EC100  ec100_internals   PH110  ph110_internals   EC110  ec110_internals  \
# 0        0               30       9               86       9               85
# 1        0               37      10               97       9               87
# 2        8               50      10               97       9               86
# 3        7               43      10               94      10               97
# 4        6               39      10               93      10               95
# 5        9               47      10               95      10               94
# 6        0               40      10               96       9               88
# 7        5               38      10               95      10               91
# 8        0               32       8               83       8               83
# 9        7               49      10               96      10               98
# 10       0               32      10               93       8               81
# 11       0               35      10               95      10               92
# 12       0               33      10               94       8               84
# 13       8               48      10               96       9               87
# 14       6               41      10               97      10               92
# 15       0               25       9               87       8               81
# 16       7               47       9               89       8               83
# 17       6               41       9               87      10               91
# 18       0               39      10               95       9               87
# 19       7               43       9               89       8               83
# 20       7               43      10               97      10               96
# 21       0               41      10               93       8               83
# 22       5               27       9               85       7               79
# 23       9               48      10               95      10               93
# 24       0               28       9               85       7               72
# 25       5               36      10               93       9               89
# 26       0               35       9               86      10               90
# 27       0               28       9               88       7               78
# 28       5               34       9               87       9               86
# 29       0               29      10               92       7               78
# 30       6               34       9               89      10               91
# 31       0               37      10               90       9               86
# 32       9               50      10               98      10               98
# 33       6               44      10               96      10               93
# 34       7               41      10               93      10               96
# 35       5               37      10               96       9               86
# 36       0               40      10               96       9               87
# 37       7               47      10               97      10               98
# 38       6               43      10               96       9               89
# 39       7               50      10               97       9               89
# 40       0               41      10               95      10               90
# 41       0               29      10               97       8               81
# 42       6               41      10               94       9               89
# 43       0               30       9               88       9               88
# 44       0               36       9               86       8               80
# 45       0               32       9               89       8               84
# 46       8               48      10               97      10               91
# 47       6               47      10               97      10               97
# 48       7               47      10               97      10               97
# 49       6               44      10               96      10               92
# 50       6               41      10               96      10               97
# 51       7               50      10               96      10               98
# 52       0               39      10               92      10               94
# 53       0               34      10               91       9               86
# 54       5               40      10               95      10               90
# 55       0               26       9               88       7               72
# 56       5               35       7               78       9               88
#
#      CS110  cs110_internals
# 0        7               75
# 1       10               98
# 2       10               97
# 3        9               87
# 4       10               98
# 5       10               97
# 6       10               94
# 7       10               93
# 8       10               94
# 9       10               95
# 10      10               91
# 11       8               82
# 12      10               94
# 13      10               90
# 14      10               98
# 15      10               94
# 16      10               91
# 17      10               99
# 18      10               94
# 19      10               93
# 20      10               97
# 21      10               97
# 22       9               87
# 23      10               96
# 24       8               82
# 25      10               92
# 26       7               79
# 27       9               87
# 28      10               91
# 29      10               94
# 30       9               88
# 31       9               89
# 32       9               88
# 33      10               91
# 34       9               88
# 35      10               91
# 36       8               84
# 37      10               91
# 38       9               89
# 39       9               89
# 40      10               96
# 41       9               85
# 42       8               81
# 43      10               96
# 44      10               92
# 45       7               75
# 46      10               95
# 47      10               95
# 48      10               97
# 49      10               95
# 50      10               94
# 51      10               90
# 52       8               81
# 53       9               89
# 54       9               87
# 55       8               82
# 56       8               81

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 19 columns):
# NO.                  57 non-null int64
# MA101                55 non-null float64
# ma_internals         57 non-null object
# PH100                57 non-null int64
# ph100_internals      57 non-null int64
#  BE10105             56 non-null float64
# be10105_internals    57 non-null int64
# BE110                57 non-null int64
# be110_internals      57 non-null int64
#  BE103               57 non-null int64
# be103_internals      57 non-null int64
#  EC100               57 non-null int64
# ec100_internals      57 non-null int64
#  PH110               57 non-null int64
# ph110_internals      57 non-null int64
#  EC110               57 non-null int64
# ec110_internals      57 non-null int64
#  CS110               57 non-null int64
# cs110_internals      57 non-null int64
# dtypes: float64(2), int64(16), object(1)
# memory usage: 8.6+ KB

# %%
result.head()
# Out:
#    NO.  MA101 ma_internals  PH100  ph100_internals   BE10105  \
# 0    1    0.0           25      0               23       0.0
# 1    2    6.0           41      7               46       7.0
# 2    3   10.0           47     10               50       6.0
# 3    5    6.0           31      9               41       5.0
# 4    6   10.0           45      7               46       0.0
#
#    be10105_internals  BE110  be110_internals   BE103  be103_internals   EC100  \
# 0                 35      8               96       5               36       0
# 1                 47      7               92       7               40       0
# 2                 47      8               74       9               46       8
# 3                 42      7               78       9               42       7
# 4                 40      6               82       7               41       6
#
#    ec100_internals   PH110  ph110_internals   EC110  ec110_internals   CS110  \
# 0               30       9               86       9               85       7
# 1               37      10               97       9               87      10
# 2               50      10               97       9               86      10
# 3               43      10               94      10               97       9
# 4               39      10               93      10               95      10
#
#    cs110_internals
# 0               75
# 1               98
# 2               97
# 3               87
# 4               98

# %%
result.to_csv (r's123.csv', index = False, header=True)

# %%
ls
# Out:
# 'Algorithms - Note for professionals.pdf'   ke/
# 'CLOUD COMPUTING'/                         'MACHINE LEARNING NOTES'/
# 'cozmo_crcted code.ipynb'                   Music/
#  cozmo.py                                  'OPERATIONAL RESEARCH'/
#  cryptography/                              PROJECT_DATASET/
# 'DATA ANALYTICS'/                          'PROJECT FINDINGS'/
#  fiverr_cosmo.ipynb                         s123.csv
# 'fritz mov-Copy1.ipynb'                    's8 question paper'/
# 'fritz mov.ipynb'                          'S8 SYLLABUS'/
# 'function mapping dataset.ipynb'            Untitled1.ipynb
# 'housing price'/                            Untitled.ipynb

# %%
result.dropna(inplace=True)

# %%
result.head(20)
# Out:
#     NO.  MA101 ma_internals  PH100  ph100_internals   BE10105  \
# 0     1    0.0           25      0               23       0.0
# 1     2    6.0           41      7               46       7.0
# 2     3   10.0           47     10               50       6.0
# 3     5    6.0           31      9               41       5.0
# 4     6   10.0           45      7               46       0.0
# 5     7    9.0           46      9               47       8.0
# 6     8    5.0           25      6               40       0.0
# 7     9    6.0           31      6               34       5.0
# 8    10    0.0           24      4               24       0.0
# 9    11    9.0           43     10               47       6.0
# 10   12    6.0           36      6               39       5.0
# 11   13    6.0           33      9               42       8.0
# 12   15    9.0           48      7               45       8.0
# 13   16   10.0           44     10               49       9.0
# 14   17    7.0           46      9               46       8.0
# 16   19    7.0           43      7               38       6.0
# 17   20    7.0           42      6               48       9.0
# 18   21    0.0           30      6               38       0.0
# 19   22   10.0           44      8               42       7.0
# 20   23    7.0           36      8               47       9.0
#
#     be10105_internals  BE110  be110_internals   BE103  be103_internals  \
# 0                  35      8               96       5               36
# 1                  47      7               92       7               40
# 2                  47      8               74       9               46
# 3                  42      7               78       9               42
# 4                  40      6               82       7               41
# 5                  48      8               79       8               45
# 6                  37      0               79       7               37
# 7                  35      0               68       6               38
# 8                  38      7               80       7               41
# 9                  45      8               83       9               50
# 10                 35      6               85       6               38
# 11                 46      7               83       7               39
# 12                 48     10               95       7               49
# 13                 50     10               93       8               44
# 14                 50     10               93       8               47
# 16                 40     10               95       7               38
# 17                 50     10               91       8               47
# 18                 38      0               77       6               36
# 19                 45      9               89       6               38
# 20                 50     10               95       8               44
#
#      EC100  ec100_internals   PH110  ph110_internals   EC110  ec110_internals  \
# 0        0               30       9               86       9               85
# 1        0               37      10               97       9               87
# 2        8               50      10               97       9               86
# 3        7               43      10               94      10               97
# 4        6               39      10               93      10               95
# 5        9               47      10               95      10               94
# 6        0               40      10               96       9               88
# 7        5               38      10               95      10               91
# 8        0               32       8               83       8               83
# 9        7               49      10               96      10               98
# 10       0               32      10               93       8               81
# 11       0               35      10               95      10               92
# 12       0               33      10               94       8               84
# 13       8               48      10               96       9               87
# 14       6               41      10               97      10               92
# 16       7               47       9               89       8               83
# 17       6               41       9               87      10               91
# 18       0               39      10               95       9               87
# 19       7               43       9               89       8               83
# 20       7               43      10               97      10               96
#
#      CS110  cs110_internals
# 0        7               75
# 1       10               98
# 2       10               97
# 3        9               87
# 4       10               98
# 5       10               97
# 6       10               94
# 7       10               93
# 8       10               94
# 9       10               95
# 10      10               91
# 11       8               82
# 12      10               94
# 13      10               90
# 14      10               98
# 16      10               91
# 17      10               99
# 18      10               94
# 19      10               93
# 20      10               97

# %%
result.to_csv (r's1_improvised.csv', index = False, header=True)

# %%
result.columns
# Out:
# Index(['NO.', 'MA101', 'ma_internals', 'PH100', 'ph100_internals', ' BE10105',
#        'be10105_internals', 'BE110', 'be110_internals', ' BE103',
#        'be103_internals', ' EC100', 'ec100_internals', ' PH110',
#        'ph110_internals', ' EC110', 'ec110_internals', ' CS110',
#        'cs110_internals'],
#       dtype='object')
